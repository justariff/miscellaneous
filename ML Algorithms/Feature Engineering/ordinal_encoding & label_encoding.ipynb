# %%
import numpy as np
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day26-ordinal-encoding/customer.csv"
df = pd.read_csv(url)
df.sample(5)
# Out:
#     age  gender   review education purchased
# 43   27    Male     Poor        PG        No
# 40   39    Male     Good    School        No
# 4    16  Female  Average        UG        No
# 16   59    Male     Poor        UG       Yes
# 46   64  Female     Poor        PG        No

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 19     Poor        PG
# 32  Average        UG
# 5   Average    School
# 3      Good        PG
# 10     Good        UG
# 20  Average    School
# 0   Average    School
# 21  Average        PG
# 4   Average        UG
# 34  Average    School
# 15     Poor        UG
# 8   Average        UG
# 27     Poor        PG
# 36     Good        UG
# 25     Good    School
# 40     Good    School
# 1      Poor        UG
# 42     Good        PG
# 24  Average        PG
# 47     Good        PG
# 16     Poor        UG
# 11     Good        UG
# 18     Good    School
# 26     Poor        PG
# 7      Poor    School
# 38     Good    School
# 39     Poor        PG
# 37  Average        PG
# 43     Poor        PG
# 23     Good    School
# 33     Good        PG
# 41     Good        PG
# 29  Average        UG
# 12     Poor    School
# 22     Poor        PG
# 2      Good        PG
# 46     Poor        PG
# 13  Average    School
# 17     Poor        UG
# 45     Poor        PG

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 oe.fit(X_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:1294, in OrdinalEncoder.fit(self, X, y)
#    1287     raise TypeError(
#    1288         "unknown_value should only be set when "
#    1289         "handle_unknown is 'use_encoded_value', "
#    1290         f"got {self.unknown_value}."
#    1291     )
#    1293 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1294 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    1296 if self.handle_unknown == "use_encoded_value":
#    1297     for feature_cats in self.categories_:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:106, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts)
#     104         cats = result
#     105 else:
# --> 106     cats = np.array(self.categories[i], dtype=Xi.dtype)
#     107     if Xi.dtype.kind not in "OUS":
#     108         sorted_cats = np.sort(cats)
#
# ValueError: could not convert string to float: 'Poor'

# %%
X_train = oe.transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 X_train = oe.transform(X_train)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:1363, in OrdinalEncoder.transform(self, X)
#    1349 def transform(self, X):
#    1350     """
#    1351     Transform X to ordinal codes.
#    1352
#    (...)
#    1361         Transformed input.
#    1362     """
# -> 1363     X_int, X_mask = self._transform(
#    1364         X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan"
#    1365     )
#    1366     X_trans = X_int.astype(self.dtype, copy=False)
#    1368     for cat_idx, missing_idx in self._missing_indices.items():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:152, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown)
#     150 for i in range(n_features):
#     151     Xi = X_list[i]
# --> 152     diff, valid_mask = _check_unknown(Xi, self.categories_[i], return_mask=True)
#     154     if not np.all(valid_mask):
#     155         if handle_unknown == "error":
#
# IndexError: list index out of range

# %%
X_train

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(Y)
